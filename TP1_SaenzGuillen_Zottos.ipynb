# %% [markdown]
# <a href="https://colab.research.google.com/github/leyresaenz1/HCPI/blob/main/TP1_SaenzGuillen_Zottos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np

# %%
#seteamos directorio
TP1 = path_parent = os.path.dirname("/Volumes/GoogleDrive-112553083728584115268/My Drive/Herramientas computacionales/Untitled/input")
print(TP1)
# Out:
# /Volumes/GoogleDrive-112553083728584115268/My Drive/Herramientas computacionales/Untitled

# %%
#Cargamos las bases de datos:
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-34f9e077-3ed7-4884-92b8-1a70857f7f25" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34f9e077-3ed7-4884-92b8-1a70857f7f25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tarea.csv to tarea (5).csv

# %%
# importamos con pandas
import pandas
filename = 'tarea.csv'
data = pandas.read_csv(filename, header=0)
df = pd.DataFrame(data)

# %%
# Mostramos las primeras 5 filas
print (df.head(5))
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# Mostramos las primeras 3 filas - acá intentamos con (.nrows==3) pero nos tiró error. 
print (df.head(3))
#print (df.nrows==3)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
#Imprimir el contenido de una columna como serie 
series = df.iloc[:,0]
print("\nFirst column as a Series:\n")
print(series)
print(type(series))
# Out:
# First column as a Series:
#
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
#Crear una nueva serie 'calidad-color'
df["calidad-color"]= df["cut"] + df["color"]
print (df)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#       calidad-color
# 0            IdealE
# ...

# %%
#Número de filas y columnas
print(data.shape)
# Out:
# (53940, 11)

# %%
#Tipos de datos de cada columna
print(data.dtypes)
# Out:
# carat            float64
# cut               object
# color             object
# clarity           object
# depth            float64
# table            float64
# price              int64
# x                float64
# y                float64
# z                float64
# calidad-color     object
# dtype: object

# %%
#Columnas objeto
df.describe(include=['object'])
# Out:
#           cut  color clarity calidad-color
# count   53940  53940   53940         53940
# unique      5      7       8            35
# top     Ideal      G     SI1        IdealG
# freq    21551  11292   13065          4884

# %%
#Rename columns color and clarity
df.rename(columns = {'color':'yellow', 'clarity':'butterfly'}, inplace = True)
list (df)
# Out:
# ['carat',
#  'cut',
#  'yellow',
#  'butterfly',
#  'depth',
#  'table',
#  'price',
#  'x',
#  'y',
#  'z',
#  'calidad-color']

# %%
#Eliminamos 2da y 3er columna
df.drop(columns=['cut', 'yellow'])
# Out:
#        carat butterfly  depth  table  price     x     y     z calidad-color
# 0       0.23       SI2   61.5   55.0    326  3.95  3.98  2.43        IdealE
# 1       0.21       SI1   59.8   61.0    326  3.89  3.84  2.31      PremiumE
# 2       0.23       VS1   56.9   65.0    327  4.05  4.07  2.31         GoodE
# 3       0.29       VS2   62.4   58.0    334  4.20  4.23  2.63      PremiumI
# 4       0.31       SI2   63.3   58.0    335  4.34  4.35  2.75         GoodJ
# ...      ...       ...    ...    ...    ...   ...   ...   ...           ...
# 53935   0.72       SI1   60.8   57.0   2757  5.75  5.76  3.50        IdealD
# 53936   0.72       SI1   63.1   55.0   2757  5.69  5.75  3.61         GoodD
# 53937   0.70       SI1   62.8   60.0   2757  5.66  5.68  3.56    Very GoodD
# 53938   0.86       SI2   61.0   58.0   2757  6.15  6.12  3.74      PremiumH
# 53939   0.75       SI2   62.2   55.0   2757  5.83  5.87  3.64        IdealD
#
# [53940 rows x 9 columns]

# %%
#Eliminamos múltiples filas a la vez
df.drop([2,3,4,8,12], axis=0, inplace=True)
df
# Out:
#        carat        cut yellow butterfly  depth  table  price     x     y  \
# 0       0.23      Ideal      E       SI2   61.5   55.0    326  3.95  3.98
# 1       0.21    Premium      E       SI1   59.8   61.0    326  3.89  3.84
# 5       0.24  Very Good      J      VVS2   62.8   57.0    336  3.94   NaN
# 6       0.24  Very Good      I      VVS1   62.3   57.0    336  3.95  3.98
# 7       0.26  Very Good      H       SI1   61.9   55.0    337  4.07  4.11
# ...      ...        ...    ...       ...    ...    ...    ...   ...   ...
# 53935   0.72      Ideal      D       SI1   60.8   57.0   2757  5.75  5.76
# 53936   0.72       Good      D       SI1   63.1   55.0   2757  5.69  5.75
# 53937   0.70  Very Good      D       SI1   62.8   60.0   2757  5.66  5.68
# 53938   0.86    Premium      H       SI2   61.0   58.0   2757  6.15  6.12
# 53939   0.75      Ideal      D       SI2   62.2   55.0   2757  5.83  5.87
#
#           z calidad-color
# 0      2.43        IdealE
# ...

# %%
#Ordenar la columna `cut’ en orden ascendente. Qué tipo de objeto es?
df.sort_values('cut', inplace=True)
df.head()
# Out:
#        carat   cut yellow butterfly  depth  table  price     x     y     z  \
# 30718   0.35  Fair      E      VVS2   66.2   61.0    738  4.40  4.36  2.90
# 19276   1.52  Fair      H       SI1   65.3   58.0   8001  7.14  7.10  4.65
# 15940   2.03  Fair      G        I1   66.3   56.0   6377  7.81  7.75  5.16
# 3839    0.90  Fair      D       SI2   64.9   57.0   3473  6.03  5.98  3.90
# 3841    0.90  Fair      D       SI2   64.5   61.0   3473  6.10  6.00  3.90
#
#       calidad-color
# 30718         FairE
# 19276         FairH
# 15940         FairG
# 3839          FairD
# 3841          FairD

# %%
#Ordenar toda la base por 'carat' en orden descendente
by_carat = df.sort_values('carat', ascending=False)
by_carat.head()
# Out:
#        carat      cut yellow butterfly  depth  table  price      x      y  \
# 27415   5.01     Fair      J        I1   65.5   59.0  18018  10.74  10.54
# 27630   4.50     Fair      J        I1   65.8   58.0  18531  10.23  10.16
# 27130   4.13     Fair      H        I1   64.8   61.0  17329  10.00   9.85
# 25998   4.01  Premium      I        I1   61.0   61.0  15223  10.14  10.10
# 25999   4.01  Premium      J        I1   62.5   62.0  15223  10.02   9.94
#
#           z calidad-color
# 27415  6.98         FairJ
# 27630  6.72         FairJ
# 27130  6.43         FairH
# 25998  6.17      PremiumI
# 25999  6.24      PremiumJ

# %%
#Filtrar aquellas filas que x>5, y>5 y z>5
print(df[(df.x > 5) & (df.y > 5) & (df.z > 5)])
# Out:
#        carat        cut yellow butterfly  depth  table  price     x     y  \
# 15940   2.03       Fair      G        I1   66.3   56.0   6377  7.81  7.75
# 22667   2.01       Fair      I       SI2   66.9   58.0  10711  7.93  7.69
# 20337   2.00       Fair      I       SI2   69.1   56.0   8736  7.84  7.70
# 17481   2.11       Fair      F        I1   67.6   57.0   7019  7.88  7.83
# 23841   2.10       Fair      G       SI2   65.0   56.0  11923  8.09  7.98
# ...      ...        ...    ...       ...    ...    ...    ...   ...   ...
# 25812   2.19  Very Good      I       SI1   62.6   58.0  14819  8.24  8.33
# 25813   2.16  Very Good      H       SI2   62.3   60.0  14824  8.19  8.31
# 19894   2.25  Very Good      J       SI2   60.6   63.0   8442  8.45  8.38
# 25815   2.31  Very Good      J       VS2   59.7   60.0  14830  8.53  8.59
# 25807   2.01  Very Good      I       SI1   62.8   60.0  14811  7.99  8.04
#
#           z calidad-color
# 15940  5.16         FairG
# ...

# %%
#Filtrar las filas para que sólo muestren `carat’ mayor a 0,4 
print(df[(df.carat > 0.4)])
# Out:
#        carat        cut yellow butterfly  depth  table  price     x     y  \
# 19276   1.52       Fair      H       SI1   65.3   58.0   8001  7.14  7.10
# 15940   2.03       Fair      G        I1   66.3   56.0   6377  7.81  7.75
# 3839    0.90       Fair      D       SI2   64.9   57.0   3473  6.03  5.98
# 3841    0.90       Fair      D       SI2   64.5   61.0   3473  6.10  6.00
# 5894    0.90       Fair      D       VS2   57.5   66.0   3931  6.30  6.25
# ...      ...        ...    ...       ...    ...    ...    ...   ...   ...
# 19887   1.24  Very Good      H      VVS2   61.3   55.0   8438  6.94  6.96
# 25807   2.01  Very Good      I       SI1   62.8   60.0  14811  7.99  8.04
# 25808   2.01  Very Good      J       VS1   61.2   60.0  14812  8.06  8.14
# 23528   1.51  Very Good      G       VS2   62.1   57.0  11532  7.37  7.32
# 9303    1.03  Very Good      H       SI1   63.5   53.0   4573  6.43  6.46
#
#           z calidad-color
# 19276  4.65         FairH
# ...

# %%
#Filtrar filas que son Premium o Ideal (tarea.cut.sin() o usar |). Acá pude poner solo 1, cómo poner 2 opciones? Osea añadir Ideal también?
df_cut=df['cut']=='Very Good'
df_cut=df['cut']=='Good'
df_cut=df['cut']=='Fair'
filtered_df = df[df_cut]
print (filtered_df)
# Out:
#        carat   cut yellow butterfly  depth  table  price     x     y     z  \
# 30718   0.35  Fair      E      VVS2   66.2   61.0    738  4.40  4.36  2.90
# 19276   1.52  Fair      H       SI1   65.3   58.0   8001  7.14  7.10  4.65
# 15940   2.03  Fair      G        I1   66.3   56.0   6377  7.81  7.75  5.16
# 3839    0.90  Fair      D       SI2   64.9   57.0   3473  6.03  5.98  3.90
# 3841    0.90  Fair      D       SI2   64.5   61.0   3473  6.10  6.00  3.90
# ...      ...   ...    ...       ...    ...    ...    ...   ...   ...   ...
# 13757   2.22  Fair      J        I1   66.7   56.0   5607  8.04  8.02  5.36
# 7896    1.00  Fair      H      VVS2   65.3   58.0   4312  6.25  6.18  4.06
# 33523   0.47  Fair      E       SI1   67.9   56.0    829  4.84  4.65  3.24
# 7897    1.00  Fair      H      VVS2   65.1   57.0   4312  6.27  6.23  4.07
# 13775   1.70  Fair      D        I1   64.7   56.0   5617  7.46  7.37  4.80
#
#       calidad-color
# 30718         FairE
# 19276         FairH
# ...

# %%
#Summary statistics
df[["carat"]].describe()
# Out:
#               carat
# count  53935.000000
# mean       0.797990
# std        0.474004
# min        0.200000
# 25%        0.400000
# 50%        0.700000
# 75%        1.040000
# max        5.010000

# %%
#Calcular la media de cada columna numérica
mean_df = df['carat'].mean()
print(mean_df)

mean_df = df['depth'].mean()
print(mean_df)

mean_df = df['table'].mean()
print(mean_df)

mean_df = df['price'].mean()
print(mean_df)

mean_df = df['x'].mean()
print(mean_df)

mean_df = df['y'].mean()
print(mean_df)

mean_df = df['z'].mean()
print(mean_df)
# Out:
# 0.7979901733568183
# 61.74941689070177
# 57.45689255585427
# 3933.13325298971
# 5.731311393343839
# 5.734714651240404
# 3.538829887827941

# %%
#Calcular la media del precio de cada tipo de `cut’
df.groupby('cut').price.mean()
# Out:
# cut
# Fair         4361.257303
# Good         3930.331770
# Ideal        3457.541970
# Premium      4584.873595
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
#Calcular la cantidad, el mínimo y el máximo precio para cada `cut’
df.groupby('cut').price.agg([])
df
# Out:
#        carat        cut yellow butterfly  depth  table  price     x     y  \
# 30718   0.35       Fair      E      VVS2   66.2   61.0    738  4.40  4.36
# 19276   1.52       Fair      H       SI1   65.3   58.0   8001  7.14  7.10
# 15940   2.03       Fair      G        I1   66.3   56.0   6377  7.81  7.75
# 3839    0.90       Fair      D       SI2   64.9   57.0   3473  6.03  5.98
# 3841    0.90       Fair      D       SI2   64.5   61.0   3473  6.10  6.00
# ...      ...        ...    ...       ...    ...    ...    ...   ...   ...
# 25808   2.01  Very Good      J       VS1   61.2   60.0  14812  8.06  8.14
# 43613   0.31  Very Good      E       SI1   63.0   58.0    507  4.29  4.31
# 43616   0.34  Very Good      G       SI1   61.5   56.0    507  4.45  4.52
# 23528   1.51  Very Good      G       VS2   62.1   57.0  11532  7.37  7.32
# 9303    1.03  Very Good      H       SI1   63.5   53.0   4573  6.43  6.46
#
#           z calidad-color
# 30718  2.90         FairE
# ...

# %%
#Mostrar los valores que puede tomar `cut’
print(df['cut'].unique())
# Out:
# ['Fair' 'Good' 'Ideal' 'Premium' 'Very Good']

# %%
#Contar cuántas veces aparece cada valor de `cut’
df.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13789
# Very Good    12082
# Good          4904
# Fair          1609
# Name: cut, dtype: int64

# %%
#Mostrar los porcentajes de cada valor de `cut’. 
df['cut'].value_counts(normalize=True)*100
# Out:
# Ideal        39.957356
# Premium      25.565959
# Very Good    22.401038
# Good          9.092426
# Fair          2.983221
# Name: cut, dtype: float64

# %%
#Calcular una tabla de doble entrada con `cut’ y `color’
pd.crosstab(df.cut, df.yellow)
# Out:
# yellow        D     E     F     G     H     I    J
# cut
# Fair        163   223   312   314   303   175  119
# Good        662   932   909   871   702   522  306
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2330  2924  2360  1427  808
# Very Good  1513  2400  2164  2299  1824  1204  678

# %%
#Crear un histograma de ‘cut’
df["cut"].hist()

# %%
#Crear un gráfico de barras de ‘cut’
import matplotlib.pyplot as plt
import plotly.express as px

x_values = df['cut'].unique()
y_values = df['cut'].value_counts().tolist()

plt.bar(x_values, y_values)
plt.show()
plt.close('all')

# %%
#Contar el número de missing valies en cada columna
df.isnull().sum()
# Out:
# carat            0
# cut              0
# yellow           0
# butterfly        0
# depth            0
# table            0
# price            0
# x                0
# y                1
# z                0
# calidad-color    0
# dtype: int64

# %%
#Comprobar el número de filas y columnas y eliminarlas si falta algún valor en una fila 
df.info()
df.dropna(how='any')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53935 entries, 30718 to 9303
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   carat          53935 non-null  float64
#  1   cut            53935 non-null  object
#  2   yellow         53935 non-null  object
#  3   butterfly      53935 non-null  object
#  4   depth          53935 non-null  float64
#  5   table          53935 non-null  float64
#  6   price          53935 non-null  int64
#  7   x              53935 non-null  float64
#  8   y              53934 non-null  float64
#  9   z              53935 non-null  float64
#  10  calidad-color  53935 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 4.9+ MB
#        carat        cut yellow butterfly  depth  table  price     x     y  \
# 30718   0.35       Fair      E      VVS2   66.2   61.0    738  4.40  4.36
# ...

# %%
#Eliminar una fila si faltan todos los valores 
df.dropna(how='all')
# Out:
#        carat        cut yellow butterfly  depth  table  price     x     y  \
# 30718   0.35       Fair      E      VVS2   66.2   61.0    738  4.40  4.36
# 19276   1.52       Fair      H       SI1   65.3   58.0   8001  7.14  7.10
# 15940   2.03       Fair      G        I1   66.3   56.0   6377  7.81  7.75
# 3839    0.90       Fair      D       SI2   64.9   57.0   3473  6.03  5.98
# 3841    0.90       Fair      D       SI2   64.5   61.0   3473  6.10  6.00
# ...      ...        ...    ...       ...    ...    ...    ...   ...   ...
# 25808   2.01  Very Good      J       VS1   61.2   60.0  14812  8.06  8.14
# 43613   0.31  Very Good      E       SI1   63.0   58.0    507  4.29  4.31
# 43616   0.34  Very Good      G       SI1   61.5   56.0    507  4.45  4.52
# 23528   1.51  Very Good      G       VS2   62.1   57.0  11532  7.37  7.32
# 9303    1.03  Very Good      H       SI1   63.5   53.0   4573  6.43  6.46
#
#           z calidad-color
# 30718  2.90         FairE
# ...

# %%
#Mostrar las filas 0, 2, 5 y todas las columnas 
df.iloc[[0, 2, 5], :].head()
# Out:
#        carat   cut yellow butterfly  depth  table  price     x     y     z  \
# 30718   0.35  Fair      E      VVS2   66.2   61.0    738  4.40  4.36  2.90
# 15940   2.03  Fair      G        I1   66.3   56.0   6377  7.81  7.75  5.16
# 5894    0.90  Fair      D       VS2   57.5   66.0   3931  6.30  6.25  3.61
#
#       calidad-color
# 30718         FairE
# 15940         FairG
# 5894          FairD

# %%
#Mostrar las filas 0 a 2 (inclusive) y las columnas 'color' y 'precio' 
df.iloc[[0, 1, 2], [2, 6]]
# Out:
#       yellow  price
# 30718      E    738
# 19276      H   8001
# 15940      G   6377

# %%
#Mostrar las filas en las que la 'cut' es 'Premium' más la columna 'color'. Acá faltó que solo nos queden las 2 columnas solitcitadas, dejamos los intentos.
#df.drop(['carat', 'butterfly', 'depth', 'table', 'price', 'x', 'y', 'z'], axis=1)
#df.loc [:,['cut', 'yellow']]
#df.loc[[df['cut'] == 'Premium', 'yellow']

df.loc[df['cut'] == 'Premium'] 
#df.drop(['carat','butterfly','depth','table','price','x','y','z'], axis=1)
# Out:
#        carat      cut yellow butterfly  depth  table  price     x     y     z  \
# 8330    1.09  Premium      H       SI2   61.2   62.0   4395  6.63  6.58  4.04
# 8224    1.06  Premium      F       SI2   62.4   58.0   4372  6.50  6.54  4.07
# 40712   0.53  Premium      H       SI1   61.2   60.0   1159  5.22  5.10  3.16
# 8331    1.09  Premium      H       SI2   61.2   62.0   4395  6.63  6.58  4.04
# 41971   0.40  Premium      F      VVS1   60.2   59.0   1263  4.74  4.76  2.86
# ...      ...      ...    ...       ...    ...    ...    ...   ...   ...   ...
# 17857   1.33  Premium      H       SI1   61.1   61.0   7204  7.05  7.02  4.30
# 15681   1.22  Premium      G       SI1   62.3   58.0   6288  6.83  6.76  4.23
# 18976   1.00  Premium      D       VS1   62.1   55.0   7812  6.41  6.34  3.96
# 26861   2.03  Premium      I       SI1   61.2   58.0  16787  8.21  8.16  5.01
# 25186   1.51  Premium      F       VS2   62.0   62.0  13771  7.35  7.23  4.52
#
#       calidad-color
# ...

# %%
#Obtener 5 filas de muestra al azar 
df.sample(5)
# Out:
#        carat        cut yellow butterfly  depth  table  price     x     y  \
# 35406   0.32      Ideal      E       VS2   61.3   57.0    900  4.45  4.42
# 48250   0.71    Premium      I       VS2   60.0   58.0   1952  5.79  5.85
# 36010   0.39  Very Good      F       SI1   63.3   54.0    921  4.67  4.62
# 6400    1.03    Premium      I       SI1   61.0   58.0   4038  6.52  6.47
# 15784   1.05      Ideal      E       SI1   60.7   55.0   6316  6.62  6.67
#
#           z calidad-color
# 35406  2.72        IdealE
# 48250  3.49      PremiumI
# 36010  2.94    Very GoodF
# 6400   3.96      PremiumI
# 15784  4.03        IdealE

# %%
#Obtener una muestra del 75% de las filas sin reemplazarlas. 
df.sample(frac=0.75)
# Out:
#        carat        cut yellow butterfly  depth  table  price     x     y  \
# 28564   0.30      Ideal      H       VS1   62.2   57.0    675  4.30  4.28
# 20509   1.25    Premium      F       VS2   61.5   60.0   8840  6.93  6.89
# 20025   0.32       Good      F       SI2   63.8   55.0    421  4.34  4.35
# 50530   0.70       Good      I       VS1   63.2   55.0   2274  5.58  5.63
# 4618    0.91  Very Good      I       VS2   61.0   57.0   3664  6.20  6.26
# ...      ...        ...    ...       ...    ...    ...    ...   ...   ...
# 10028   0.29       Good      F       VS1   62.1   56.0    415  4.24  4.26
# 40787   0.40      Ideal      F      VVS1   61.9   55.0   1168  4.75  4.78
# 3657    0.73  Very Good      F      VVS2   61.9   59.0   3442  5.72  5.84
# 3975    0.90  Very Good      E       SI1   62.9   57.0   3510  6.11  6.17
# 34012   0.43      Ideal      F       VS2   61.4   54.0    848  4.90  4.93
#
#           z calidad-color
# 28564  2.67        IdealH
# ...

# %%
#Contar las filas duplicadas
#print(df[df.duplicated()])
#print(df.duplicated(keep=False))
print(df.duplicated().sum())
# Out:
# 146
