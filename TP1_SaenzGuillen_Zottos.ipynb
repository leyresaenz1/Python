# %%
#seteamos directorio
import os
import pandas as pd
import numpy as np 
TP1 = path_parent = os.path.dirname("/Volumes/GoogleDrive-112553083728584115268/My Drive/Herramientas computacionales/TP1/input")
print(TP1)
# Out:
# /Volumes/GoogleDrive-112553083728584115268/My Drive/Herramientas computacionales/TP1

# %%
#Cargamos la bases de datos:
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d311cd7e-996a-494f-a96d-8e88440b8e80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d311cd7e-996a-494f-a96d-8e88440b8e80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tarea.csv to tarea (4).csv

# %%
filename = 'tarea.csv'
data = pd.read_csv(filename, header=0)

# %%
df = pd.DataFrame(data)

# %%
print (data.head(5))
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
print (data.head(3))
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31

# %%
#Imprimir el contenido de una columna como serie 
series = df.iloc[:,0]
print("\nFirst column as a Series:\n")
print(series)
print(type(series))
# Out:
# First column as a Series:
#
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
#Crear una nueva serie 'calidad-color' CHEQUEAR
s = pd.Series(['calidad-color'])
s
# Out:
# 0    calidad-color
# dtype: object

# %%
#Número de filas y columnas
print(data.shape)
# Out:
# (53940, 10)

# %%
#Tipos de datos de cada columna
print(data.dtypes)
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
#Columnas objeto
df.describe(include=['object'])
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %%
#Rename columns color and clarity
df.rename(columns = {'color':'yellow', 'clarity':'butterfly'}, inplace = True)
list (df)
# Out:
# ['carat',
#  'cut',
#  'yellow',
#  'butterfly',
#  'depth',
#  'table',
#  'price',
#  'x',
#  'y',
#  'z']

# %%
#Eliminamos 2 y 3 columna
df.drop(columns=['cut', 'yellow'])
# Out:
#        carat butterfly  depth  table  price     x     y     z
# 0       0.23       SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21       SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29       VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...       ...    ...    ...    ...   ...   ...   ...
# 53935   0.72       SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70       SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86       SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75       SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 8 columns]

# %%
#Eliminamos múltiples filas a la vez
df.drop([2,3,4,8,12], axis=0, inplace=True)
df
# Out:
#        carat        cut yellow butterfly  depth  table  price     x     y  \
# 0       0.23      Ideal      E       SI2   61.5   55.0    326  3.95  3.98
# 1       0.21    Premium      E       SI1   59.8   61.0    326  3.89  3.84
# 5       0.24  Very Good      J      VVS2   62.8   57.0    336  3.94   NaN
# 6       0.24  Very Good      I      VVS1   62.3   57.0    336  3.95  3.98
# 7       0.26  Very Good      H       SI1   61.9   55.0    337  4.07  4.11
# ...      ...        ...    ...       ...    ...    ...    ...   ...   ...
# 53935   0.72      Ideal      D       SI1   60.8   57.0   2757  5.75  5.76
# 53936   0.72       Good      D       SI1   63.1   55.0   2757  5.69  5.75
# 53937   0.70  Very Good      D       SI1   62.8   60.0   2757  5.66  5.68
# 53938   0.86    Premium      H       SI2   61.0   58.0   2757  6.15  6.12
# 53939   0.75      Ideal      D       SI2   62.2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# 1      2.31
# 5      2.48
# 6      2.47
# ...

# %%
#Ordenar la columna `cut’ en orden ascendente 
df.sort_values('cut', inplace=True)
df.head()
# Out:
#        carat   cut yellow butterfly  depth  table  price     x     y     z
# 30718   0.35  Fair      E      VVS2   66.2   61.0    738  4.40  4.36  2.90
# 19276   1.52  Fair      H       SI1   65.3   58.0   8001  7.14  7.10  4.65
# 15940   2.03  Fair      G        I1   66.3   56.0   6377  7.81  7.75  5.16
# 3839    0.90  Fair      D       SI2   64.9   57.0   3473  6.03  5.98  3.90
# 3841    0.90  Fair      D       SI2   64.5   61.0   3473  6.10  6.00  3.90

# %%
#Ordenar toda la base por 'carat' en orden descendente
by_carat = df.sort_values('carat', ascending=False)
by_carat.head()
# Out:
#        carat   cut yellow butterfly  depth  table  price     x     y     z
# 27739   2.80  Good      G       SI2   63.8   58.0  18788  8.90  8.85  0.00
# 25899   2.48  Fair      I       SI2   56.7   66.0  15030  8.88  8.64  4.99
# 24523   2.29  Fair      J       SI1   56.8   66.0  12811  8.79  8.69  4.96
# 25137   2.29  Fair      J       VS2   57.0   66.0  13701  8.80  8.60  4.98
# 26559   2.26  Good      I       SI2   56.9   60.0  16241  8.73  8.66  4.95

# %%
#Filtrar aquellas filas que x>5, y>5 y z>5
print(df[(df.x > 5) & (df.y > 5) & (df.z > 5)])
# Out:
#        carat        cut color clarity  depth  table  price     x      y      z
# 11778   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28   5.12
# 13002   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70   5.36
# 13118   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95   5.23
# 13562   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56   5.04
# 13757   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02   5.36
# ...      ...        ...   ...     ...    ...    ...    ...   ...    ...    ...
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97   5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47   5.16
# 48410   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15  31.80
# 49189   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80   5.12
# 49905   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04   5.06
#
# ...

# %%
#Filtrar las filas para que sólo muestren `carat’ mayor a 0,4 
print(df[(df.carat > 0.4)])
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 64      0.42    Premium     I     SI2   61.5   59.0    552  4.78  4.84  2.96
# 90      0.70      Ideal     E     SI1   62.5   57.0   2757  5.70  5.72  3.57
# 91      0.86       Fair     E     SI2   55.1   69.0   2757  6.45  6.33  3.52
# 92      0.70      Ideal     G     VS2   61.6   56.0   2757  5.70  5.67  3.50
# 93      0.71  Very Good     E     VS2   62.4   57.0   2759  5.68  5.73  3.56
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [39549 rows x 10 columns]

# %%
#Filtrar filas que son Premium o Ideal (tarea.cut.sin() o usar |)
df.cut.sin()
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
#Summary statistics
df[["carat"]].describe()
# Out:
#               carat
# count  53940.000000
# mean       0.797940
# std        0.474011
# min        0.200000
# 25%        0.400000
# 50%        0.700000
# 75%        1.040000
# max        5.010000

# %%
#Calcular la media de cada columna numérica
mean_df = df['carat'].mean()
print(mean_df)

mean_df = df['depth'].mean()
print(mean_df)

mean_df = df['table'].mean()
print(mean_df)

mean_df = df['price'].mean()
print(mean_df)

mean_df = df['x'].mean()
print(mean_df)

mean_df = df['y'].mean()
print(mean_df)

mean_df = df['z'].mean()
print(mean_df)
# Out:
# 0.7979397478680014
# 61.749404894327036
# 57.45718390804598
# 3932.799721913237
# 5.731157211716722
# 5.734558853519717
# 3.5387337782721544

# %%
#Calcular la media del precio de cada tipo de `cut’
df.groupby('cut').price.mean()
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %%
#Mostrar los valores que puede tomar `cut’
print(df['cut'].unique())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']

# %%
#Contar cuántas veces aparece cada valor de `cut’
df.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
#NO ME SALE ESTE!!!!!
df ['percent'] =(df ['cut'] / df['cut']. sum()) * 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-4bf37dba86c9> in <module>()
# ----> 1 df ['percent'] =(df ['cut'] / df['cut']. sum()) * 100
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ...

# %%
#Calcular una tabla de doble entrada con `cut’ y `color’
pd.crosstab(df.cut, df.color)
# Out:
# color         D     E     F     G     H     I    J
# cut
# Fair        163   224   312   314   303   175  119
# Good        662   933   909   871   702   522  307
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2331  2924  2360  1428  808
# Very Good  1513  2400  2164  2299  1824  1204  678

# %%
#Crear un histograma de ‘cut’--> NO ME SALE SOLO CON COLUMNA CUT
df.plot(kind='hist')

# %%
#Crear un gráfico de barras de ‘cut’--> NO ME SALE SOLO CON COLUMNA CUT
df.plot(kind = 'bar')

# %%
#Contar el número de missing valies en cada columna
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-515a097d2aa1> in <module>()
#       1 #Contar el número de missing valies en cada columna
# ----> 2 df.isnull().sum()
#
# NameError: name 'df' is not defined
